# %%
import numpy as np
import pandas as pd
import copy
data = pd.read_csv(r"C:/Users/kinyh/Desktop/DeepLearning_Project/student/student-por.csv")
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
import matplotlib.pyplot as plt
from numpy import genfromtxt
data = genfromtxt('C:/Users/kinyh/Desktop/DeepLearning_Project/1.csv',delimiter=',')
period = ['Frist Period Grade','Second Period Grade','Final Grade']
plt.plot(data)
plt.xlabel('Student ')
plt.ylabel('Grades')
plt.title('Students Academic Performance in Different Grade Periods')
plt.show()

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
# school        649 non-null object
# sex           649 non-null object
# age           649 non-null int64
# address       649 non-null object
# famsize       649 non-null object
# Pstatus       649 non-null object
# Medu          649 non-null int64
# Fedu          649 non-null int64
# Mjob          649 non-null object
# Fjob          649 non-null object
# reason        649 non-null object
# guardian      649 non-null object
# traveltime    649 non-null int64
# studytime     649 non-null int64
# failures      649 non-null int64
# schoolsup     649 non-null object
# famsup        649 non-null object
# paid          649 non-null object
# activities    649 non-null object
# nursery       649 non-null object
# higher        649 non-null object
# internet      649 non-null object
# romantic      649 non-null object
# famrel        649 non-null int64
# ...

# %%
data.boxplot('absences','address')

# %%
objOnlyData = data.select_dtypes(include=['object']).copy()
objOnlyData.head()
# Out:
#   school sex address famsize Pstatus     Mjob      Fjob  reason guardian  \
# 0     GP   F       U     GT3       A  at_home   teacher  course   mother
# 1     GP   F       U     GT3       T  at_home     other  course   father
# 2     GP   F       U     LE3       T  at_home     other   other   mother
# 3     GP   F       U     GT3       T   health  services    home   mother
# 4     GP   F       U     GT3       T    other     other    home   father
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0       yes     no   no         no     yes    yes       no       no
# 1        no    yes   no         no      no    yes      yes       no
# 2       yes     no   no         no     yes    yes      yes       no
# 3        no    yes   no        yes     yes    yes      yes      yes
# 4        no    yes   no         no     yes    yes       no       no

# %%
print(objOnlyData.isnull().sum())
# Out:
# school        0
# sex           0
# address       0
# famsize       0
# Pstatus       0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
Mjob_count = objOnlyData['Mjob'].value_counts()
sns.set(style="darkgrid")
sns.barplot(Mjob_count.index, Mjob_count.values, alpha= 0.9)
plt.title('Mother job Frequency')
plt.ylabel('y', fontsize=12)
plt.xlabel('x', fontsize=12)
plt.show()

# %%
def heatmap(x, y, size):
    fig, ax = plt.subplots()
    
    # Mapping from column names to integer coordinates
    x_labels = [v for v in sorted(x.unique())]
    y_labels = [v for v in sorted(y.unique())]
    x_to_num = {p[1]:p[0] for p in enumerate(x_labels)} 
    y_to_num = {p[1]:p[0] for p in enumerate(y_labels)} 
    
    size_scale = 500
    ax.scatter(
        x=x.map(x_to_num), # Use mapping for x
        y=y.map(y_to_num), # Use mapping for y
        s=size * size_scale, # Vector of square sizes, proportional to size parameter
        marker='s' # Use square as scatterplot marker
    )
    
    # Show column labels on the axes
    ax.set_xticks([x_to_num[v] for v in x_labels])
    ax.set_xticklabels(x_labels, rotation=45, horizontalalignment='right')
    ax.set_yticks([y_to_num[v] for v in y_labels])
    ax.set_yticklabels(y_labels)
columns = ['internet', 'studytime', 'paid', 'romantic', 'freetime', 'absences'] 
corr = data[columns].corr()
orr = pd.melt(corr.reset_index(), id_vars='index') # Unpivot the dataframe, so we can get pair of arrays for x and y
corr.columns = ['x', 'y', 'value']
heatmap(
    x=corr['x'],
    y=corr['y'],
    size=corr['value'].abs()
)

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
# Label Encoded catergorical data
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
X = data.iloc[:, 0:30]
X = X.apply(le.fit_transform)
y = data.iloc[:, 30:33]

# %%
#Split data into trainning set and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
#Training and Predictions
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000)
mlp.fit(X_train, y_train.values.ravel())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-4b8dbf2e2d88> in <module>
#       2 from sklearn.neural_network import MLPClassifier
#       3 mlp = MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000)
# ----> 4 mlp.fit(X_train, y_train.values.ravel())
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\neural_network\multilayer_perceptron.py in fit(self, X, y)
#     980         """
#     981         return self._fit(X, y, incremental=(self.warm_start and
# --> 982                                             hasattr(self, "classes_")))
#     983
#     984     @property
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\neural_network\multilayer_perceptron.py in _fit(self, X, y, incremental)
#     321                              hidden_layer_sizes)
#     322
# --> 323         X, y = self._validate_input(X, y, incremental)
# ...
